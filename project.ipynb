# %% [markdown]
# # Fundamentals of Data Analysis Project
# **Olga Knutova**
# ***
# I this noutbook we are investigating the variables and
# data points within the well-known iris flower data set associated
# with Ronald A Fisher.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First we will import libraries we going to use, then load the Data set.

# %%
iris_df=sns.load_dataset("iris")

# %% [markdown]
# Now we will have a look at the strusture of the Data set.

# %%
print(iris_df.head())
print("------")
print("shape:", iris_df.shape)
print("------")
print(iris_df["species"].value_counts())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# ------
# shape: (150, 5)
# ------
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# We can see that this data set has 5 variables and 150 records or data points. Iris data set is balanced as it hase same number of records for each species.

# %% [markdown]
# ##### Classification of each variable within the data set according to common variable types and scales of measurement in mathematics, statistics, and Python.

# %% [markdown]
# Four variables ( **sepal length, sepal width, petal length, petal width**) are very similar. They are quantitative continuous variables with ratio scales of masurment. so we can compare them to each other and look at their ratio.

# %%
pairplot = sns.pairplot(iris_df,hue="species")
plt.show()

# %% [markdown]
# **Species** is nominal or qualitative categorical variable. Using this variable we can have 3 subsets in our data set and analyse each species separatly.

# %% [markdown]
# We can check what types of data used to record variables in data frame.

# %%
iris_df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# As we can see again variable "species" is standing out it is object and recorder as a string.
# Other four variables recorder as floats.

# %% [markdown]
# ##### Select, demonstrate, and explain the most appropriate summary statistics to describe each variable.
#
# Here are the main statistical values:
# - **count**-	Total number of entries
# - **mean**-	Average of all the entries
# - **std**-	Standard deviation
# - **min**-	Minimum value
# - **25%**-	25 percentile mark
# - **50%**-	50 percentile mark (median)
# - **75%**-	75 percentile mark
# - **max**-	Maximum value

# %% [markdown]
# We can look at the statistical values for all data set.

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# or just for one variable.

# %%
iris_df["sepal_length"].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %% [markdown]
# Looking at statistical values for each species separatly and comparing them will give us more information about differenses between species.

# %%
setosa_df = iris_df[iris_df["species"] == "setosa"]
setosa_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
versicolor_df = iris_df[iris_df["species"] == "versicolor"]

versicolor_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
virginica_df = iris_df[iris_df["species"] == "virginica"]
virginica_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
setosa_df["sepal_length"].describe()
# Out:
# count    50.00000
# mean      5.00600
# std       0.35249
# min       4.30000
# 25%       4.80000
# 50%       5.00000
# 75%       5.20000
# max       5.80000
# Name: sepal_length, dtype: float64

# %% [markdown]
# ##### Select, demonstrate, and explain the most appropriate plot(s) for each variable

# %% [markdown]
# ##### **Species**
# For qualitative categorical variable the pie plot is most appropriat in my opinion. It visualuse percentage of each species in data set. We can see strate away that data set is balanced.

# %%
ax=iris_df['species'].value_counts().plot(kind='pie',autopct='%1.1f%%')

ax.legend( title="species", loc="best", bbox_to_anchor=(1, 0, 0.5, 1))
ax.yaxis.set_visible(False)
ax.set_title("Value Count Pie Chart-Species%")
plt.show()

# %% [markdown]
# Plotting four quantitative variables ( **sepal length, sepal width, petal length, petal width**) will have similar concept. We want to visualise differenc in mesurments for eachspesies and find is there any masurment that can be used for identification of the speces.

# %% [markdown]
# ##### **Sepal Length**
# We will start with bar plot.
# It is demonstratinf difference between species in sepal lenght, but we can't see is there any overlap in values.
# "Show point estimates and errors as rectangular bars.
#
# A bar plot represents an aggregate or statistical estimate for a numeric variable with the height of each rectangle and indicates the uncertainty around that estimate using an error bar. Bar plots include 0 in the axis range, and they are a good choice when 0 is a meaningful value for the variable to take."
# Bar - mean value
# Error bar- confidence interval around the estimate (defolt 95%)

# %%
sns.catplot(data=iris_df, x="species", y="sepal_length", kind="bar").set(title="Sepal length Bar plot")
plt.show()

# %% [markdown]
# Histogram on the other hand is demonstrating if values of variable for different species are overlaping. It gives us detaled picture of collected data but looks a bit busy.

# %%
for species in iris_df['species'].unique():
    subset = iris_df[iris_df['species'] == species]
    plt.hist(subset['sepal_length'], bins=10, alpha=0.5, label=species)

plt.legend(loc='upper right')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
plt.title('Histogram of Sepal Lengths by Species')
plt.show()

# %% [markdown]
# Box plot This plot shows the median, quartiles, and outliers of the data using rectangular boxes and whiskers. In very simple way it gives us cleare picture of statistical vlues of a variable and how they compared for species.

# %%
sns.boxplot(x="species", y="sepal_length",
            hue="species", palette=["blue", "orange", "green"],
            data=iris_df).set(title="Sepal length Box plot")
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# ##### **Sepal Width**

# %%
sns.catplot(data=iris_df, x="species", y="sepal_width", kind="bar").set(title="Sepal width Bar plot")
plt.show()

# %%
for species in iris_df['species'].unique():
    subset = iris_df[iris_df['species'] == species]
    plt.hist(subset['sepal_width'], bins=10, alpha=0.5, label=species)

plt.legend(loc='upper right')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
plt.title('Histogram of Sepal Width by Species')
plt.show()

# %%
sns.boxplot(x="species", y="sepal_width",
            hue="species", palette=["blue", "orange", "green"],
            data=iris_df).set(title="Sepal width Box plot")
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# ##### **Petal Length**

# %%
sns.catplot(data=iris_df, x="species", y="petal_length", kind="bar").set(title="Petal length Bar plot")
plt.show()

# %%
for species in iris_df['species'].unique():
    subset = iris_df[iris_df['species'] == species]
    plt.hist(subset['petal_length'], bins=10, alpha=0.5, label=species)

plt.legend(loc='upper right')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count')
plt.title('Histogram of Petal Lengths by Species')
plt.show()

# %%
sns.boxplot(x="species", y="petal_length",
            hue="species", palette=["blue", "orange", "green"],
            data=iris_df).set(title="Petal length Box plot")
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# ##### **Petal Width**

# %%
sns.catplot(data=iris_df, x="species", y="petal_width", kind="bar").set(title="Petal width Bar plot")
plt.show()

# %%
for species in iris_df['species'].unique():
    subset = iris_df[iris_df['species'] == species]
    plt.hist(subset['petal_width'], bins=10, alpha=0.5, label=species)

plt.legend(loc='upper right')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Count')
plt.title('Histogram of Petal Widt by Species')
plt.show()

# %%
sns.boxplot(x="species", y="petal_width",
            hue="species", palette=["blue", "orange", "green"],
            data=iris_df).set(title="Petal width Box plot")
sns.despine(offset=10, trim=True)
plt.show()

# %% [markdown]
# Conclusion:
# After investigating the variables and
# data points within the A Fisher iris flower data set we can say that Setosa has a smalest petals and can be identified by both petal width and petal length mesurments.
# For versicolor and virginica we don't have a variable that can be used to idetify species with high level of confidens. Petals and sepals of versicolor in general are smaller than virginica but extream values are overlaping.

# %% [markdown]
# ******
# # References
# #### [1] [seaborn](https://seaborn.pydata.org)
# #### [2] [w3school](https://www.w3schools.com/)
# #### [3] [geeksforgeeks](https://www.geeksforgeeks.org/)

# %% [markdown]
# ***
# ## End
